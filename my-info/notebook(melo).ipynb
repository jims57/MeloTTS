# %%
# !rm -rf ~/.local/share/Trash/*

# %%
# !rm /root/CosyVoice/zero_shot_0.wav
# !rm /root/CosyVoice/zero_shot_1.wav
# !rm /root/CosyVoice/zero_shot_2.wav
# !rm /root/CosyVoice/zero_shot_3.wav
# !rm /root/CosyVoice/cosy_mp3_chunks/*
# !rm /root/MeloTTS/melo_audio_chunks/chunk_*.mp3
# !rm /root/MeloTTS/melo_audio_chunks/chunk_*.pcm

# !rm -rf ~/.local/share/Trash/*
# Out:
# rm: cannot remove '/root/CosyVoice/zero_shot_0.wav': No such file or directory
# rm: cannot remove '/root/CosyVoice/zero_shot_1.wav': No such file or directory
# rm: cannot remove '/root/CosyVoice/zero_shot_2.wav': No such file or directory
# rm: cannot remove '/root/CosyVoice/zero_shot_3.wav': No such file or directory
# rm: cannot remove '/root/CosyVoice/cosy_mp3_chunks/*': No such file or directory
# rm: cannot remove '/root/MeloTTS/melo_audio_chunks/chunk_*.mp3': No such file or directory

# %% [raw]
# source /root/cosy/bin/activate

# %%
#!python combine_all_wavs_into_a_single_wav.py

from IPython.display import Audio, display
import os

audio_file_path = os.path.expanduser('~/MeloTTS/speech.mp3')


# Check if the file exists before trying to play it
if os.path.exists(audio_file_path):
    print(f"Playing audio from: {audio_file_path}")
    display(Audio(audio_file_path))
else:
    print(f"Error: Audio file not found at {audio_file_path}")
    print("Please ensure the file path is correct and the file exists.")
# Out:
# Playing audio from: /root/MeloTTS/speech.mp3
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Image history

# %% [markdown]
# ### (save-image)
#
# //>>login repository
# docker login --username=jimmy@1904289922758417 crpi-e59jvk2aewsjh4xc.cn-shanghai.personal.cr.aliyuncs.com
# pwd: watchfun.cn888
#
# version="1.3.3"
# server_name="melo-tts"
# image_prefix_watch="d.watchfun.cn/jims57"
# image_name_watch="${image_prefix_watch}/${server_name}"
# image_prefix="crpi-e59jvk2aewsjh4xc.cn-shanghai.personal.cr.aliyuncs.com/watchfun-fc3-space"
# image_name="${image_prefix}/${server_name}"
# tag="v${version}"
#
# version="1.3.3" && server_name="melo-tts" && image_prefix="jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker commit --pause=false "${server_name}" "${image_name}:${tag}"
#
# (push-image-only)
# version="1.3.3" && server_name="melo-tts" && image_prefix="jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker push "${image_name}:${tag}"
#
# (save-and-push-image)//>>save image
# version="1.3.3" && server_name="melo-tts" && image_prefix="jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker commit --pause=false "${server_name}" "${image_name_watch}:${tag}" && docker push "${image_name_watch}:${tag}"
#
# version="1.3.3" && server_name="melo-tts" && image_prefix="jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker commit --pause=false "${server_name}" "${image_name}:${tag}" && docker push "${image_name}:${tag}"
#
# (docker pull)
# version="1.3.3" && server_name="melo-tts" && image_prefix="jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker pull "${image_name}:${tag}"
#
# (start-docker)//>>start container>>run container
# version="1.3.3" && server_name="melo-tts" && image_prefix="jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker rm "${server_name}" -f && docker run --gpus all -it -p 7860:7860 -p 8080:8080 -p 9000:9000 -p 9001:9001 -p 9002:9002 -p 9003:9003 --shm-size=16g -w /root/MeloTTS --name "${server_name}" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh && cd ~/MeloTTS &&/root/MeloTTS/melotts/bin/python melo-api.py --port 9001 && /bin/bash"
#
# (>>history)
# v1.3.6:
#     * update api_documentation.html and add /apiDoc api
#     * make the mp3 streams faster(change from 1s to 0.25s) using chunkDuration field in post data
# v1.3.5:
#     * (important) make mp3 streams gapless
# v1.3.4:
#     * add language field and use speaker accordingly.
# v1.3.3:
#     * save a new docker image based on v1.3.2 to fix v1.3.2 image corrupted
# v1.3.2:
#     * add header(startTimeId and messageId) to each pcm
# v1.3.1:
#     * add api key to /tts websocket
#     * add HEAD in /root api so Aliyun ALB health check
# v1.3:
#     * add language field and use speaker accordingly.
# v1.2:
#     * split long text by punctuations to speed up the first chunk arrival
# v1.1:
#     * show first chunk related time info at the end
#     * send empty chunk finally.
#     * 【important】install ffmpeg
#     * improve mp3 extraction logic by referencing cosy-api.py
#     * send empty chunk after all chunks are sent to clients
# v1.0:
#     * change /tts to websocket from http, and make cosy-api.py work
#     * delete all cosy related env
#     * install MeloTTS and Jupyter

# %% [markdown]
# # run multi docker containers

# %% [markdown]
# docker rm "melo-tts-1" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="0-3" -p 9000:9000 -p 9001:9001 --shm-size=3g -w /root/ MeloTTS --name "melo-tts-1" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh; /bin/bash"
#
# version="1.3.3"
# server_name="melo-tts"
# image_prefix="jims57"
# image_name="${image_prefix}/melo-tts"
# tag="v${version}"
#
# docker rm "melo-tts-1" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="0-3" -p 9000:9000 -p 9001:9001 --shm-size=3g -w /root/MeloTTS --name "melo-tts-1" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh; /bin/bash"
#
# docker rm "melo-tts-2" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="4-7" -p 9002:9002 --shm-size=3g -w /root/MeloTTS --name "melo-tts-2" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh; /bin/bash"
#
# docker rm "melo-tts-3" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="8-11" -p 9003:9003 --shm-size=3g -w /root/MeloTTS --name "melo-tts-3" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh; /bin/bash"
#
# docker rm "melo-tts-4" -f && docker rm "${server_name}" -f && docker run --gpus all -it --cpus="4" --memory="16g" --cpuset-cpus="12-15" -p 9004:9004 --shm-size=3g -w /root/MeloTTS --name "melo-tts-4" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh; /bin/bash"

# %% [markdown]
# # Other notes

# %% [raw]
# source /root/MeloTTS/melotts/bin/activate
#
# find ~ -type f -name "activate" -path "*/bin/activate" 2>/dev/null
#
# cd ~/MeloTTS &&/root/MeloTTS/melotts/bin/python melo-api.py --port 9003
#
# (run melo api)//>>run melo api>>run api>>start melo api
# cd ~/MeloTTS && rm pretrained_models/CosyVoice2-0.5B/flow.decoder.estimator.fp16.mygpu.plan &&/root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9001
# cd ~/MeloTTS &&/root/MeloTTS/melotts/bin/python melo-api.py --port 9001
#
# cd ~/MeloTTS && rm pretrained_models/CosyVoice2-0.5B/flow.decoder.estimator.fp16.mygpu.plan &&/root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9002
# cd ~/MeloTTS &&/root/MeloTTS/melotts/bin/python melo-api.py --port 9002
#
# cd ~/MeloTTS && rm pretrained_models/CosyVoice2-0.5B/flow.decoder.estimator.fp16.mygpu.plan &&/root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9003
# cd ~/MeloTTS &&/root/MeloTTS/melotts/bin/python melo-api.py --port 9003
#
# cd ~/MeloTTS && rm pretrained_models/CosyVoice2-0.5B/flow.decoder.estimator.fp16.mygpu.plan &&/root/CosyVoice/cosy_vllm/bin/python cosy-api.py --port 9003
# cd ~/MeloTTS &&/root/MeloTTS/melotts/bin/python melo-api.py --port 9004
#
# cd ~/MeloTTS && /root/MeloTTS/melotts/bin/python melo-api.py
